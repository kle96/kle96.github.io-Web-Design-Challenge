# %%
import pandas as pd

# %%
# import CSV as dataframe
df = pd.read_csv("./city_weather.csv", index_col=0)

# %%
df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   New Norfolk -42.7826  147.0587     51.71        80         100
# 1  Constitución -35.3333  -72.4167     57.47        71          68
# 2      Cherskiy  68.7500  161.3000     34.66        89          23
# 3       Ushuaia -54.8000  -68.3000     49.66        57          75
# 4          Baní  18.2833  -70.3333     90.84        55          99
#
#    Wind Speed Country        Date
# 0        3.00      AU  1661885990
# 1        7.90      CL  1661885991
# 2       12.48      RU  1661885991
# 3        5.75      AR  1661885992
# 4       12.30      DO  1661885992

# %%
df_html = df.to_html()
print(df_html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Wind Speed</th>
#       <th>Country</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>New Norfolk</td>
#       <td>-42.7826</td>
#       <td>147.0587</td>
#       <td>51.71</td>
#       <td>80</td>
#       <td>100</td>
#       <td>3.00</td>
#       <td>AU</td>
#       <td>1661885990</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Constitución</td>
#       <td>-35.3333</td>
#       <td>-72.4167</td>
#       <td>57.47</td>
#       <td>71</td>
#       <td>68</td>
#       <td>7.90</td>
#       <td>CL</td>
#       <td>1661885991</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Cherskiy</td>
#       <td>68.7500</td>
#       <td>161.3000</td>
# ...

# %%
#Save inside data_page.html
data_page = open("../Visualizations/data_page.html", "w")
data_page.write(df_html)
data_page.close()
